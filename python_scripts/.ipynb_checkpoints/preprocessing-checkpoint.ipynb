# %% [markdown]
# # Importing Libraries

# %%
import os
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, find_peaks

# %% [markdown]
# # Importing files

# %%
filename = "assessment_centre_cleaned.csv"
path = "C:\\Users\\ieliz\\Documents\\2021\\FYP\\Stress_Detection_FYP\\python_scripts\\"

# %%
os.chdir(path)
print(os.getcwd())
df = pd.read_csv(filename)
df["Time (hr:min:sec)"] = pd.to_datetime(df["Time (hr:min:sec)"], format="%H:%M:%S").dt.time
# Out:
# C:\Users\ieliz\Documents\2021\FYP\Stress_Detection_FYP\python_scripts

# %%
df
# Out:
#       Time (hr:min:sec)  Time (s)  Serial data    Resistance  \
# 0              08:30:01         1          356  111282.05130
# 1              08:30:02         2          356  111282.05130
# 2              08:30:03         3          355  110445.85990
# 3              08:30:04         4          355  110445.85990
# 4              08:30:05         5          355  110445.85990
# ...                 ...       ...          ...           ...
# 12379          11:59:56     12596          278   67521.36752
# 12380          11:59:57     12597          276   66779.66102
# 12381          11:59:58     12598          277   67148.93617
# 12382          11:59:59     12599          276   66779.66102
# 12383          12:00:00     12600          276   66779.66102
#
#        Conductance (uS)       Section  Stressed
# 0              8.986175  Introduction         0
# 1              8.986175  Introduction         0
# 2              9.054210  Introduction         0
# 3              9.054210  Introduction         0
# 4              9.054210  Introduction         0
# ...                 ...           ...       ...
# 12379         14.810127        GA Q&A         0
# 12380         14.974619        GA Q&A         0
# 12381         14.892269        GA Q&A         0
# 12382         14.974619        GA Q&A         0
# 12383         14.974619        GA Q&A         0
#
# [12384 rows x 7 columns]

# %% [markdown]
# # Calculating Conductance

# %%
# df["Conductance (uS)"] = 1*10**6/df["Resistance"]

# %% [markdown]
# # Cleaning data (for discontinuities)

# %%
# df = df.drop(list(range(3774,3989)))

# %%
fig, ax = plt.subplots()
ax.set_xlim((0, len(df)))
ax.set_ylim((0, max(df["Conductance (uS)"])))
ax.set_title('Feather Analog Read')
ax.set_xlabel("time (s)")
ax.set_ylabel("Conductance)")
ax.plot(df["Time (s)"], df["Conductance (uS)"])

# %% [markdown]
# # Pre-processing Data
# ## Moving average filter

# %%
df_moving_ave = df
df_moving_ave["Conductance (uS)"] = df["Conductance (uS)"].rolling(2).mean() #1 second moving average filter
df_moving_ave = df_moving_ave.dropna()

# %%
df_moving_ave
# Out:
#       Time (hr:min:sec)  Time (s)  Serial data    Resistance  \
# 1              08:30:02         2          356  111282.05130
# 2              08:30:03         3          355  110445.85990
# 3              08:30:04         4          355  110445.85990
# 4              08:30:05         5          355  110445.85990
# 5              08:30:06         6          355  110445.85990
# ...                 ...       ...          ...           ...
# 12379          11:59:56     12596          278   67521.36752
# 12380          11:59:57     12597          276   66779.66102
# 12381          11:59:58     12598          277   67148.93617
# 12382          11:59:59     12599          276   66779.66102
# 12383          12:00:00     12600          276   66779.66102
#
#        Conductance (uS)       Section  Stressed
# 1              8.986175  Introduction         0
# 2              9.020193  Introduction         0
# 3              9.054210  Introduction         0
# 4              9.054210  Introduction         0
# 5              9.054210  Introduction         0
# ...                 ...           ...       ...
# 12379         14.769159        GA Q&A         0
# 12380         14.892373        GA Q&A         0
# 12381         14.933444        GA Q&A         0
# 12382         14.933444        GA Q&A         0
# 12383         14.974619        GA Q&A         0
#
# [12383 rows x 7 columns]

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, len(df_moving_ave))
ax.set_ylim(0, max(df_moving_ave['Conductance (uS)']))
ax.set_title('Feather Analog Read')
ax.set_xlabel("time (s)")
ax.set_ylabel("Conductance)")
ax.plot(df_moving_ave['Time (s)'], df_moving_ave['Conductance (uS)'])

# %% [markdown]
# ## Min-Max Normalisation

# %%
min_val = min(df_moving_ave['Conductance (uS)'])
max_val = max(df_moving_ave['Conductance (uS)'])
scaling = max_val-min_val
df_moving_ave.loc[:, 'Normalised'] = (df_moving_ave.loc[:, 'Conductance (uS)']- min_val)/scaling
# Out:
# c:\users\ieliz\documents\2021\fyp\stress_detection_fyp\fyp_dev\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# c:\users\ieliz\documents\2021\fyp\stress_detection_fyp\fyp_dev\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_moving_ave
# Out:
#       Time (hr:min:sec)  Time (s)  Serial data    Resistance  \
# 1              08:30:02         2          356  111282.05130
# 2              08:30:03         3          355  110445.85990
# 3              08:30:04         4          355  110445.85990
# 4              08:30:05         5          355  110445.85990
# 5              08:30:06         6          355  110445.85990
# ...                 ...       ...          ...           ...
# 12379          11:59:56     12596          278   67521.36752
# 12380          11:59:57     12597          276   66779.66102
# 12381          11:59:58     12598          277   67148.93617
# 12382          11:59:59     12599          276   66779.66102
# 12383          12:00:00     12600          276   66779.66102
#
#        Conductance (uS)       Section  Stressed  Normalised
# 1              8.986175  Introduction         0    0.110071
# 2              9.020193  Introduction         0    0.112342
# 3              9.054210  Introduction         0    0.114613
# 4              9.054210  Introduction         0    0.114613
# 5              9.054210  Introduction         0    0.114613
# ...                 ...           ...       ...         ...
# 12379         14.769159        GA Q&A         0    0.496140
# 12380         14.892373        GA Q&A         0    0.504366
# 12381         14.933444        GA Q&A         0    0.507108
# 12382         14.933444        GA Q&A         0    0.507108
# 12383         14.974619        GA Q&A         0    0.509857
#
# [12383 rows x 8 columns]

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, len(df_moving_ave))
ax.set_ylim(0, max(df_moving_ave['Normalised']))
ax.set_title('Feather Analog Read')
ax.set_xlabel("time (s)")
ax.set_ylabel("Conductance)")
ax.plot(df_moving_ave['Time (s)'], df_moving_ave['Normalised'])

# %% [markdown]
# # Feature Extraction

# %%
unique_sections = df_moving_ave["Section"].unique()
unique_sections_num = df_moving_ave["Section"].nunique()
print(unique_sections)

labels = []
for name in unique_sections:
    curr_label = df_moving_ave.loc[df_moving_ave["Section"] == name, 'Stressed'].unique()[0]
    labels.append(curr_label)
    
print(labels)
# Out:
# ['Introduction' 'Questions' 'Break' 'Interview' 'GA Prep'
#  'GA Reading Time' 'GA Discussion' 'GA Presentation' 'GA Q&A']
# [0, 0, 0, 1, 1, 1, 0, 1, 0]

# %% [markdown]
# ## Extract Phasic components

# %% [markdown]
# ## Applying low pass filter

# %%
def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %% [markdown]
# ## Identifying onset and offset of stressor
# ## Find peaks and maximum amplitude
# ## Find average GSR

# %%
# For each section of data from assessment centre
# Label as stressed/not stressed
# Find peak, maximum amplitude and average GSR
# Training data: peak, max and average GSR + label

# %%
# Storing values
peaks = []
max_peaks = []
num_peaks = []
average_GSRs = []

# Filter requirements
order = 6
fs = 60      # sample rate, Hz
cutoff = 20  # desired cutoff frequency of the filter, Hz

# %%
# Low pass filter
y = butter_lowpass_filter(df_moving_ave["Normalised"], cutoff, fs, order)
df_moving_ave["LPF"] = y
fig, ax = plt.subplots()
ax.set_title('Filtered Data')
ax.set_xlabel("time (s)")
ax.set_ylabel("Conductance)")
ax.plot(df_moving_ave['Time (s)'],df_moving_ave["Normalised"])
ax.plot(df_moving_ave['Time (s)'],y)
# Out:
# <ipython-input-18-3f7d61883da2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_moving_ave["LPF"] = y

# %%
for i in range(unique_sections_num):
    grouped = df_moving_ave.groupby(df_moving_ave["Section"])
    section = grouped.get_group(unique_sections[i])
    time = section['Time (s)'].to_numpy()
    data = section["LPF"].to_numpy()
    #print('time', time, data)
    
    fig, ax = plt.subplots()
    ax.set_title('Filtered Data')
    ax.set_xlabel("time (s)")
    ax.set_ylabel("Conductance)")
    ax.plot(time, data)
    
    curr_peaks_ind, _ = find_peaks(data)
    curr_peaks = data[curr_peaks_ind]
    max_peak = max(curr_peaks)

    ax.plot(time[curr_peaks_ind],curr_peaks, "x")
    
    peaks.append(curr_peaks)
    num_peaks.append(len(curr_peaks))
    max_peaks.append(max_peak)
    
    ave = np.mean(data)
    average_GSRs.append(ave)
    
    print(i, max_peak, ave, labels[i])
# Out:
# 0 0.7016192606814715 0.13217795005094268 0
# 1 0.5408892402448483 0.3696474960580094 0
# 2 0.6894140678745859 0.2683555407112498 0
# 3 0.8593318020736553 0.5375172173881375 1
# 4 0.930712292575874 0.7848208322343083 1
# 5 0.8875134979079147 0.7966210968678554 1
# 6 0.938574739762604 0.6222928801060287 0
# 7 1.0008375686363657 0.7270232065178298 1
# 8 0.912500942655404 0.7116033473707966 0

# %%
print("max_peaks", max_peaks)
print("average_GSRs", average_GSRs)
print("labels", labels)
# Out:
# max_peaks [0.7016192606814715, 0.5408892402448483, 0.6894140678745859, 0.8593318020736553, 0.930712292575874, 0.8875134979079147, 0.938574739762604, 1.0008375686363657, 0.912500942655404]
# average_GSRs [0.13217795005094268, 0.3696474960580094, 0.2683555407112498, 0.5375172173881375, 0.7848208322343083, 0.7966210968678554, 0.6222928801060287, 0.7270232065178298, 0.7116033473707966]
# labels [0, 0, 0, 1, 1, 1, 0, 1, 0]

# %%
stress_df = pd.DataFrame()
stress_df['Max'] = pd.Series(max_peaks)
stress_df['AveGSR'] = pd.Series(average_GSRs)
stress_df['Stress'] = pd.Series(labels)
stress_df
# Out:
#         Max    AveGSR  Stress
# 0  0.701619  0.132178       0
# 1  0.540889  0.369647       0
# 2  0.689414  0.268356       0
# 3  0.859332  0.537517       1
# 4  0.930712  0.784821       1
# 5  0.887513  0.796621       1
# 6  0.938575  0.622293       0
# 7  1.000838  0.727023       1
# 8  0.912501  0.711603       0

# %% [markdown]
# # K-Nearest Neighbours

# %%
from sklearn import neighbors
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
n_neighbours = 3
X = stress_df.loc[:, ['Max', 'AveGSR']]
y = stress_df.loc[:, 'Stress']

# %%
# Colour maps
cmap_light = ListedColormap(['cyan', 'cornflowerblue'])
cmap_dark = ['c', 'darkblue']
h = 0.02 # step size in mesh

# %%
weight = 'uniform'#'distance'
clf = neighbors.KNeighborsClassifier(n_neighbours, weight)
clf.fit(X, y)

x_min, x_max = X.iloc[:, 0].min()-1, X.iloc[:, 0].max() + 1
y_min, y_max = X.iloc[:, 1].min()-1, X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# Put result into a colour plot
Z = Z.reshape(xx.shape)
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=cmap_light)

# Plot also the training points
sns.scatterplot(x=X.iloc[:, 0], y=X.iloc[:, 1], hue=y,
                palette=cmap_dark, alpha=1.0, edgecolor="black")
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("2-Class classification")
plt.show()
# Out:
# c:\users\ieliz\documents\2021\fyp\stress_detection_fyp\fyp_dev\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass weights=uniform as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
for i in range(len(stress_df)):
    predicted_label = clf.predict([stress_df.iloc[i, 0:2]])[0]
    print(i)
    actual_label = stress_df.iloc[i, 2] 

    if predicted_label == 1:
        print("Predicted: Stressed")
    else:
        print("Predicted: Not Stressed")

    if actual_label == 1:
        print("Actual: Stressed")
    else:
        print("Actual: Not Stressed")
# Out:
# 0
# Predicted: Not Stressed
# Actual: Not Stressed
# 1
# Predicted: Not Stressed
# Actual: Not Stressed
# 2
# Predicted: Not Stressed
# Actual: Not Stressed
# 3
# Predicted: Not Stressed
# Actual: Stressed
# 4
# Predicted: Stressed
# Actual: Stressed
# 5
# Predicted: Stressed
# Actual: Stressed
# 6
# Predicted: Not Stressed
# Actual: Not Stressed
# 7
# Predicted: Stressed
# Actual: Stressed
# 8
# Predicted: Stressed
# Actual: Not Stressed
